# %% [markdown]
# # <span style="color:blue"><p style='text-align:center;'>Employees Details Exploratory Data Analysis </p></span>

# %% [markdown]
# *The dataset "Employees Details Working in ABC Company" comprises nine variables intended for exploring employee characteristics. These variables include:*
#
# - <span style="color:red">**Name**</span>     : Employees name.
# - <span style="color:red">**Team**</span>     : Employees divided into 30 distinct groups.
# - <span style="color:red">**Number**</span>   : Number assigned to the employees.
# - <span style="color:red">**Position**</span> : Categorized into 5 positions: **('PG', 'SF', 'SG', 'PF', 'C')**.
# - <span style="color:red">**Age**</span>      : Age of the employees.
# - <span style="color:red">**Height**</span>   : Instead of Height, the dataset provides Dates.
# - <span style="color:red">**Weight**</span>   : Weight of the employees.
# - <span style="color:red">**College**</span>  : Colleges from which the employees graduated.
# - <span style="color:red">**Salary**</span>   : Salaries of the employees.
#
# It's important to note that this dataset is fictitious and is utilized solely for demonstrating basic data analysis skills. Any findings or conclusions drawn from this dataset should not be considered official or used to infer actual relationships between the variables and employee details.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('new.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.notnull()
# Out:
#      Name  Team  Number  Position   Age  Height  Weight  College  Salary
# 0    True  True    True      True  True    True    True     True    True
# 1    True  True    True      True  True    True    True     True    True
# 2    True  True    True      True  True    True    True     True   False
# 3    True  True    True      True  True    True    True     True    True
# 4    True  True    True      True  True    True    True    False    True
# ..    ...   ...     ...       ...   ...     ...     ...      ...     ...
# 453  True  True    True      True  True    True    True     True    True
# 454  True  True    True      True  True    True    True    False    True
# 455  True  True    True      True  True    True    True    False    True
# 456  True  True    True      True  True    True    True     True    True
# 457  True  True    True      True  True    True    True     True    True
#
# [458 rows x 9 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df.Team.nunique()
# Out:
# 30

# %%
df.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
df.Position.nunique()
# Out:
# 5

# %%
df['Number']
# Out:
# 0       0
# 1      99
# 2      30
# 3      28
# 4       8
#        ..
# 453     8
# 454    25
# 455    21
# 456    24
# 457    34
# Name: Number, Length: 458, dtype: int64

# %%
Height=np.random.randint(150,180,size=458)
df['Height']=Height
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     164     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     152     203
# 454      Raul Neto       Utah Jazz      25       PG   24     178     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     179     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     151     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ##

# %% [markdown]
# ### <span style="color:red">1.How many are there in each Team and the percentage splitting with respect to the total employees?</span>

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
plt.figure(figsize=(25,6))
plt.xticks(rotation="vertical")
sns.countplot(x='Team',data=df,hue='Team',palette='plasma')
# Out:
# <Axes: xlabel='Team', ylabel='count'>

# %%
no_of_team=30

# %%
no_of_employee=458

# %%
team_series=pd.Series(df['Team'].value_counts())
percentage=(team_series/no_of_employee)*100
result=pd.concat([team_series,percentage.round(2)],axis=1)
result.columns=['Number of employee','Percentage']
result
# Out:
#                         Number of employee  Percentage
# Team
# New Orleans Pelicans                    19        4.15
# Memphis Grizzlies                       18        3.93
# Utah Jazz                               16        3.49
# New York Knicks                         16        3.49
# Milwaukee Bucks                         16        3.49
# Brooklyn Nets                           15        3.28
# Portland Trail Blazers                  15        3.28
# Oklahoma City Thunder                   15        3.28
# Denver Nuggets                          15        3.28
# Washington Wizards                      15        3.28
# Miami Heat                              15        3.28
# Charlotte Hornets                       15        3.28
# Atlanta Hawks                           15        3.28
# San Antonio Spurs                       15        3.28
# Houston Rockets                         15        3.28
# Boston Celtics                          15        3.28
# ...

# %% [markdown]
# **Data Story** :
#     *The countplot analysis based on the employee teams reveals that the team has the highest number of employees, closely followed by the 'Memphis Grizzlies' team, which comprises 18 employees. Consequently, the splitting percentage, or the proportion of the total workforce, was also notably highest for these respective teams.*

# %% [markdown]
# ##

# %% [markdown]
# ### <span style="color:red">2.Segregate the employees w.r.t different positions?</span>

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df[['Position','Name']]
# Out:
#     Position           Name
# 0         PG  Avery Bradley
# 1         SF    Jae Crowder
# 2         SG   John Holland
# 3         SG    R.J. Hunter
# 4         PF  Jonas Jerebko
# ..       ...            ...
# 453       PG   Shelvin Mack
# 454       PG      Raul Neto
# 455        C   Tibor Pleiss
# 456        C    Jeff Withey
# 457        C       Priyanka
#
# [458 rows x 2 columns]

# %%
# Grouping employees by position
grouped_by_position = df.groupby('Position')

# %%
# Displaying only 'Name' and 'Position' columns for each position group
for position, group in grouped_by_position:
    print(f"Position: {position}")
    print(group[['Name', 'Position']])
    print("\n")
# Out:
# Position: C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
#
# Position: PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
#
# Position: PG
#               Name Position
# 0    Avery Bradley       PG
# 8     Terry Rozier       PG
# ...

# %%
unique_positions = df['Position'].unique()
print("Unique Positions:", unique_positions)
plt.figure(figsize=(8,6))
plt.title('Employee Count by Position')
sns.countplot(x='Position',data=df,hue='Position',palette='dark')
# Out:
# Unique Positions: ['PG' 'SF' 'SG' 'PF' 'C']
# <Axes: title={'center': 'Employee Count by Position'}, xlabel='Position', ylabel='count'>

# %% [markdown]
# ### **Data Story**
#
# *According to the countplot analysis:*
#
# - **SG Position:** There were 102 employees who worked in this position.
# - **PG Position:** There were 100 employees who worked in this position.
#
# *Other positions may have different counts, but 'SG' had the highest count followed closely by 'PF'.*

# %% [markdown]
# ####

# %% [markdown]
# ### <span style="color:red">3.Find from which age group most of the employees belong to?</span>

# %%
df['Age']
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %%
df['Age'].nunique()
# Out:
# 22

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Age',data=df,hue='Age',palette='cividis')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df['Age Group'] = df['Age'].apply(lambda age:'20-25' if 20 <= age <= 25 else ('26-30' if 26 <= age <= 30 else ('31-35' if 31 <= age <= 35 else '36 -40')))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     164     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     152     203
# 454      Raul Neto       Utah Jazz      25       PG   24     178     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     179     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     151     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     20-25
# ...

# %%
df['Age Group'].value_counts()
# Out:
# Age Group
# 20-25     198
# 26-30     167
# 31-35      68
# 36 -40     25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Age Group',data=df,hue='Age Group',palette='magma')
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %% [markdown]
# ### Data Story:
#  - Most of the employees fall within the age of 24, with 42 individuals in this group. Close behind are 41 employees aged 25.
#  - The majority of employees, totaling 198 individuals, are aged between 20 and 25, constituting the highest number within this age range. In contrast, there are fewer employees, specifically 25 individuals, within the 36 to 40 age range.

# %% [markdown]
# ####

# %% [markdown]
# ### <span style="color:red">4.Find out under which team and position, spending in terms of salary is high?</span>

# %%
x = df['Salary'].mean()
df['Salary'].fillna(x,inplace = True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     155     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     164     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     173     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     152     203
# 454      Raul Neto       Utah Jazz      25       PG   24     178     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     179     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     151     231
#
#                College        Salary Age Group
# ...

# %%
df1=df[['Team','Position','Salary']]
df1
# Out:
#                Team Position        Salary
# 0    Boston Celtics       PG  7.730337e+06
# 1    Boston Celtics       SF  6.796117e+06
# 2    Boston Celtics       SG  4.833970e+06
# 3    Boston Celtics       SG  1.148640e+06
# 4    Boston Celtics       PF  5.000000e+06
# ..              ...      ...           ...
# 453       Utah Jazz       PG  2.433333e+06
# 454       Utah Jazz       PG  9.000000e+05
# 455       Utah Jazz        C  2.900000e+06
# 456       Utah Jazz        C  9.472760e+05
# 457       Utah Jazz        C  9.472760e+05
#
# [458 rows x 3 columns]

# %%
total_salary = df1.groupby(['Team', 'Position'])['Salary'].sum()
max_spending = total_salary.idxmax()
max_spending_salary = total_salary.max()
print(f"The team and position with the highest spending is:\n Team: {max_spending[0]}\n position: {max_spending[1]} \n with a total salary of {max_spending_salary}.")
# Out:
# The team and position with the highest spending is:
#  Team: Los Angeles Lakers
#  position: SF
#  with a total salary of 31866445.0.

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(y="Salary", x="Team", hue="Position", data=df1)
plt.ylabel("Salary")
plt.xlabel("Team")
plt.title("Scatter Plot of Position vs Team with high Salary")
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Data Story:
#
# -scatter plot gives salary distribution accross different position within each team.it reveal that Los angeles lakers satndout highest spending team

# %% [markdown]
# ### <span style="color:red">5.Find if there is any correlation between age and salary , represent it visually?</span>

# %%
df2=df[['Age','Salary']]
df2
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
corr = df2.corr()
print(corr)
sns.heatmap(corr, annot=True, cmap="viridis")
plt.title("Correlation Matrix between Age and Salary of Employee Dataset")
plt.show()
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %% [markdown]
# ### Data Story:
# The correlation shows the relationship between "Age" and "Salary" in the employee dataset:
#
# - **Age vs. Age (1.00000)** : This value of 1.00000 along the diagonal represents the correlation of a variable with itself, which is always 1. It indicates a perfect positive correlation, as expected.
#
# - **Age vs. Salary (0.21117)** : The correlation coefficient of 0.21117 suggests a positive but relatively weak relationship between age and salary. This means that as age increases, there's a tendency for salaries to increase slightly, but the correlation isn't very strong.
#
# - Similarly, **Salary vs. Age (0.21117)** : Since correlation is a symmetric measure, this value mirrors the correlation between "Age" and "Salary" and reaffirms the weak positive relationship between the two variables.
#
# In simpler terms, the correlation matrix indicates that there's a positive but not particularly strong relationship between age and salary in the employee dataset. As employees' ages tend to increase, there is a tendency for their salaries to slightly rise.
